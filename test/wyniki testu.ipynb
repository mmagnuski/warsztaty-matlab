# %%
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
wyniki = pd.read_excel('wyniki.xlsx')
wyniki.head()
# Out:
#       ID  1a  1b  1c  2a  2b  2c  3a  3b  3c    ...     8  9   10   11   12  \
# 0  34809   1   1   0   1   0   0   1   0   3    ...     3  1  1.5  1.5  3.5
# 1  36281   1   1   0   1   2   2   1   1   3    ...     3  1  1.5  1.5  3.0
# 2  24493   1   0   2   1   2   2   1   1   2    ...     3  1  1.5  1.5  2.0
# 3  35565   1   1   2   1   2   2   1   1   3    ...     3  1  1.5  1.5  0.0
# 4  23847   1   1   2   1   2   2   1   1   3    ...     3  1  1.5  1.5  0.0
#
#      13    14    sum  max      perc
# 0  2.00  2.00  36.50   46  0.793478
# 1  3.00  2.00  40.75   46  0.885870
# 2  1.25  2.00  38.25   46  0.831522
# 3  2.00  1.75  36.75   46  0.798913
# 4  1.75  2.00  37.00   46  0.804348
#
# [5 rows x 29 columns]

# %%
g = sns.kdeplot(wyniki['perc'], bw=0.2, shade=True, clip=(0,1))
g.set_xlim((0.38,1.1))
# Out:
# (0.38, 1.1)
# c:\Miniconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
max_pnt = wyniki.apply(max, axis=0)
mean_pnt = wyniki.apply(np.mean)
diffic = max_pnt - mean_pnt
diffic = diffic.drop(['ID', 'sum', 'max', 'perc'])
diffic.plot(figsize=(15,4), title='trudność pytań');

# %%
all_points = wyniki.drop(['ID', 'sum', 'max', 'perc'], axis=1)
all_points.transpose().plot(figsize=(14,6), legend=False)
